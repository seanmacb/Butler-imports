# %%
import lsst.afw.image as afwImage
import matplotlib.pyplot as plt
import numpy as np
import csv
import pandas as pd
from astropy.io import ascii

# %%
path = "/sdf/data/rubin/repo/main/DECam/communityProcessed/decade_coadds/taiga/deca_archive/DEC/multiepoch/delve_deep/r5768/DES0017-4123/p01/coadd/DES0017-4123_r5768p01_r.fits.fz"

# %%
exp = afwImage.ExposureF
w = exp.readFits(path)
# Out:
# <pre style="margin: 0.1em;
# padding-left: 0.25em;
# border-left-style: solid;
# font-family: var(--jp-code-font-family);
# font-size: var(--jp-code-font-size);
# line-height: var(--jp-code-line-height);
# "><span style="color: var(--jp-warn-color2)">lsst.afw.image.MaskedImageFitsReader</span> <span style="color: var(--jp-warn-color0)">WARNING</span>: Expected extension type not found: IMAGE</pre>

# %%
plt.imshow(w.image.array,vmin=-5,vmax=5)
plt.colorbar()
plt.show()

# %%
w.getMetadata()
# Out:
# TTYPE1 = "COMPRESSED_DATA"
# // label for field   1
# TFORM1 = "1PB(8526)"
# // data format of field: variable length array
# TTYPE2 = "ZSCALE"
# // label for field   2
# TFORM2 = "1D"
# // data format of field: 8-byte DOUBLE
# TTYPE3 = "ZZERO"
# // label for field   3
# TFORM3 = "1D"
# // data format of field: 8-byte DOUBLE
# EXTNAME = "SCI"
# GAIN = 49.094790621580
# // Maximum equivalent gain (e-/ADU)
# SATURATE = 26658.859835190
# // Saturation Level (ADU)
# SOFTNAME = "SWarp"
# // The software that processed those data
# SOFTVERS = "2.40.1"
# // Version of the software
# SOFTDATE = "2021-06-12"
# // Release date of the software
# SOFTAUTH = "2010-2012 IAP/CNRS/UPMC"
# // Maintainer of the software
# SOFTINST = "IAP  http://www.iap.fr"
# // Institute
# AUTHOR = "unknown"
# // Who ran the software
# ORIGIN = "ccc0010.campuscluster.illinois.edu"
# // Where it was done
# DATE = "2022-01-11T07:18:16"
# // When it was started (GMT)
# COMBINET = "WEIGHTED"
# // COMBINE_TYPE config parameter for SWarp
# COMMENT = [ " Propagated FITS keywords", " Axis-dependent config parameters" ]
# BUNIT = "COUNTS/S"
# // units of pixels
# FILTER = "r DECam SDSS c0002 6415.0 1480.0"
# // Unique filter identifier
# BAND = "r"
# // Short name for filter
# TILENAME = "DES0017-4123"
# // DES Tilename
# TILEID = 117018
# // Tile ID for DES Tilename
# RESAMPT1 = "LANCZOS3"
# // RESAMPLING_TYPE config parameter
# CENTERT1 = "MANUAL"
# // CENTER_TYPE config parameter
# PSCALET1 = "MANUAL"
# // PIXELSCALE_TYPE config parameter
# RESAMPT2 = "LANCZOS3"
# // RESAMPLING_TYPE config parameter
# CENTERT2 = "MANUAL"
# // CENTER_TYPE config parameter
# PSCALET2 = "MANUAL"
# // PIXELSCALE_TYPE config parameter
# DESFNAME = "DES0017-4123_r5768p01_r.fits"
# // DES production filename
# PIPELINE = "multiepoch"
# // DESDM pipeline name
# REQNUM = 5768
# // DESDM processing request number
# UNITNAME = "DES0017-4123"
# // DESDM processing unit name
# ATTNUM = 1
# // DESDM processing attempt number
# EUPSPROD = "MEPipeline"
# // eups pipeline meta-package name
# EUPSVER = "Y5A1dev+59"
# // eups pipeline meta-package version
# DES_EXT = "IMAGE"
# // DES name of the extension
# FZALGOR = "RICE_1"
# // Compression type
# FZDTHRSD = "CHECKSUM"
# // Dithering seed value
# FZQVALUE = 16
# // Compression quantization factor
# FZQMETHD = "SUBTRACTIVE_DITHER_2"
# // Compression quantization method
# RA_CENT = 4.4455836881963
# // RA center
# DEC_CENT = -41.388925527767
# // DEC center
# RAC1 = 4.9351064799404
# // RA corner 1
# DECC1 = -41.753086195490
# // DEC corner 1
# RAC2 = 3.9559635200596
# // RA corner 2
# DECC2 = -41.753086195490
# // DEC corner 2
# RAC3 = 3.9614331822240
# // RA corner 3
# DECC3 = -41.022639957344
# // DEC corner 3
# RAC4 = 4.9296368177760
# // RA corner 4
# DECC4 = -41.022639957344
# // DEC corner 4
# RACMIN = 3.9559635200596
# // Minimum extent of image in RA
# RACMAX = 4.9351064799404
# // Maximum extent of image in RA
# DECCMIN = -41.753086195490
# // Minimum extent of image in Declination
# DECCMAX = -41.022639957344
# // Maximum extent of image in Declination
# CROSSRA0 = "N"
# // Does Image Span RA 0h (Y/N)
# MAGZERO = 30.000000000000
# // Mag Zero-point in magnitudes/s
# HISTORY = [ "Tue Jan 11 02:01:30 2022 column_interp over mask 0x0001", "Image was compressed by CFITSIO using scaled integer quantization:", "  q = 16.000000 / quantized level scaling parameter", "'SUBTRACTIVE_DITHER_2' / Pixel Quantization Algorithm" ]
# ZDITHER0 = 2019
# // dithering offset when quantizing floats

# %% [markdown]
# ## Butler command to ingest files

# %% [raw]
# Usage: butler ingest-files [OPTIONS] REPO DATASET_TYPE RUN TABLE_FILE
#
#   Ingest files from table file.
#
#   REPO is the URI or path to an existing data repository root or configuration
#   file.
#
#   DATASET_TYPE is the name of the dataset type to be associated with these
#   files. This dataset type must already exist and will not be created by this
#   command. There can only be one dataset type per invocation of this command.
#
#   RUN is the run to use for the file ingest.
#
#   TABLE_FILE refers to a file that can be read by astropy.table with columns
#   of:
#
#   file URI, dimension1, dimension2, ..., dimensionN
#
#   where the first column is the URI to the file to be ingested and the
#   remaining columns define the dataId to associate with that file. The column
#   names should match the dimensions for the specified dataset type. Relative
#   file URI by default is assumed to be relative to the current working
#   directory but can be overridden using the ``--prefix`` option.
#
#   This command does not create dimension records and so any records must be
#   created by other means. This command should not be used to ingest raw camera
#   exposures.
#
# Options:
#   --formatter TEXT                Fully-qualified python class to use as the
#                                   Formatter. If not specified the formatter
#                                   will be determined from the dataset type and
#                                   datastore configuration.
#   --id-generation-mode [UNIQUE|DATAID_TYPE|DATAID_TYPE_RUN]
#                                   Mode to use for generating dataset IDs. The
#                                   default creates a unique ID. Other options
#                                   are: 'DATAID_TYPE' for creating a
#                                   reproducible ID from the dataID and dataset
#                                   type; 'DATAID_TYPE_RUN' for creating a
#                                   reproducible ID from the dataID, dataset
#                                   type and run. The latter is usually used for
#                                   'raw'-type data that will be ingested in
#                                   multiple. repositories.
#   --data-id TEXT                  Keyword=value string with an additional
#                                   dataId value that is fixed for all ingested
#                                   files. This can be used to simplify the
#                                   table file by removing repeated entries that
#                                   are fixed for all files to be ingested.
#                                   Multiple key/values can be given either by
#                                   using comma separation or multiple command
#                                   line options.
#   --prefix TEXT                   For relative paths in the table file,
#                                   specify a prefix to use. The default is to
#                                   use the current working directory.
#   --track-file-attrs / --no-track-file-attrs
#                                   Indicate to the datastore whether file
#                                   attributes such as file size or checksum
#                                   should be tracked or not. Whether this
#                                   parameter is honored depends on the specific
#                                   datastore implementation.
#   -t, --transfer [auto|link|symlink|hardlink|copy|move|relsymlink|direct]
#                                   The external data transfer mode.
#   -h, --help                      Show this message and exit.
#
#   See 'butler --help' for more options.

# %%
import lsst.daf.butler as daf_butler
from astropy.coordinates import SkyCoord
from astropy import units as u
import lsst.geom as geom
import os
import astropy.table as table

# %%
but = daf_butler.Butler("/repo/main")

# %%
but.registry.queryDatasetTypes("template_coadd")
# Out:
# [DatasetType('template_coadd', {band, skymap, tract, patch}, ExposureF)]

# %%
REPO = "/repo/main"
DATASET_TYPE = "template_coadd"
RUN = "/DECam/DECADE/coadds"
TABLE_FILE = "tableFile.csv"

# %%
def makeCLIQuery(repo,datasetType,run,tableFile):
    return "butler ingest-files {} {} {} {}".format(repo,datasetType,run,tableFile)

# %%
makeCLIQuery(REPO,DATASET_TYPE,RUN,TABLE_FILE)
# Out:
# 'butler ingest-files /repo/main template_coadd /DECam/DECADE/coadds tableFile.csv'

# %%
tab = table.Table()
skymaps = but.registry.queryDatasets("skyMap",collections='DECam/defaults')
decamSkymap_ringsv1 = list(skymaps)[2]
result = but.get(decamSkymap_ringsv1)

# %%
fnames = np.array(["DES0301-0458_r6450p01_g.fits.fz","DES0301-0458_r6450p01_i.fits.fz","DES0301-0458_r6450p01_r.fits.fz","DES0301-0458_r6450p01_z.fits.fz"])
ra, dec = fnames[0][0:12][3:7],fnames[0][0:12][7:] # The hhmm and ddmm form of ra and dec
    
ra_h = int(ra[0:2]) # string stripping
ra_m = int(ra[2:])
dec_deg = int(dec[1:3])
dec_m = int(dec[3:])
offset = dec[0] # computing if dec is +/- the equator

finalRa = (ra_h*15+ra_m/60)*u.deg # final RA

if offset=="-": # final DEC
    finalDec = -1 * (dec_deg+dec_m/60)*u.deg
else: 
    finalDec = (dec_deg+dec_m/60)*u.deg

coord=SkyCoord(finalRa,finalDec,frame="icrs")

# %%
DESCMP2_pathList = pd.read_csv("fullPathList_fz.txt",names=["fname"])

# %%
baseDir = "/sdf/group/rubin/repo/main/DECam/communityProcessed/decade_coadds"

dataArr = []

for localPath in DESCMP2_pathList['fname']:

    fullPath = baseDir+localPath

    tileName = fullPath.split("/")[-4]
    
    # subDirFiles = np.array(os.listdir(os.path.join(baseDir,subDir)))
    
    # msk = [(x.endswith(".fits.fz") and not (x.__contains__("nobkg") or x.__contains__("det"))) for x in subDirFiles]
    # msk = [(x.endswith(".fits.fz") and x.__contains__("nobkg") and not x.__contains__("det")) for x in subDirFiles]
    
    # filteredFiles = np.array(subDirFiles)[msk]
    
    ra, dec = tileName[3:7],tileName[7:] # The hhmm and ddmm form of ra and dec
    
    ra_h = int(ra[0:2]) # string stripping
    ra_m = int(ra[2:])
    dec_deg = int(dec[1:3])
    dec_m = int(dec[3:])
    offset = dec[0] # computing if dec is +/- the equator
    
    finalRa = (ra_h*15+ra_m/60)*u.deg # final RA
    
    if offset=="-": # final DEC
        finalDec = -1 * (dec_deg+dec_m/60)*u.deg
    else: 
        finalDec = (dec_deg+dec_m/60)*u.deg
    
    coord=SkyCoord(finalRa,finalDec,frame="icrs")

    tractInf,patchInf = result.findClosestTractPatchList([geom.SpherePoint(geom.Angle(coord.ra.deg/(180/np.pi)),geom.Angle(coord.dec.deg/(180/np.pi)))])[0]
    
    band = fullPath.split("/")[-1].split(".")[0].split("_")[-1].lower()

    dataArr.append([fullPath,band,str(decamSkymap_ringsv1.dataId["skymap"]),tractInf.getId(),patchInf[0].getSequentialIndex()])

# %%
dataDF = pd.DataFrame(np.array(dataArr),columns=["filename","band","skymap","tract","patch"])
band_tract_patch = dataDF["band"]+"_"+dataDF["tract"]+"_"+dataDF['patch']
uniq_band_tract_patch,indices,counts = np.unique(band_tract_patch,return_index=True,return_counts=True)
dataDF.iloc[indices].to_csv(TABLE_FILE,index=False,header=True)

# %%
table = ascii.read(TABLE_FILE)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[165], line 2
#       1 for t in table['filename']:
# ----> 2     Path(str(t)).touch()
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.0.0/lib/python3.12/pathlib.py:1303, in Path.touch(self, mode, exist_ok)
#    1301 if not exist_ok:
#    1302     flags |= os.O_EXCL
# -> 1303 fd = os.open(self, flags, mode)
#    1304 os.close(fd)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/DECam/communityProcessed/decade_coadds/taiga/deca_archive/DEC/multiepoch/delve/r6435/DES0518+0335/p01/coadd/DES0518+0335_r6435p01_g.fits.fz'

# %%
str(t)
# Out:
# '/sdf/group/rubin/repo/main/DECam/communityProcessed/decade_coadds/taiga/deca_archive/DEC/multiepoch/delve/r6435/DES1820-8820/p01/coadd/DES1820-8820_r6435p01_z.fits.fz'

# %% [markdown]
# ## Now, what command should be entered to ingest this data?

# %%
but.registry.queryDatasetTypes("template_coadd")
# Out:
# [DatasetType('template_coadd', {band, skymap, tract, patch}, ExposureF)]

# %%
test = list(but.registry.queryDatasets("template_coadd",collections="/DECam/DECADE/coadds",where="skymap='decam_rings_v1'"))

# %%
exp = but.get(test[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 exp = but.get(test[0])
#
# IndexError: list index out of range

# %%
plt.imshow(exp.image.array,vmin=-3,vmax=4)
plt.colorbar()
plt.show()
